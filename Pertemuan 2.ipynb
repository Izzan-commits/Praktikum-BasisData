# %% [markdown]
# <a href="https://colab.research.google.com/github/Izzan-commits/Praktikum-BasisData/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Bab 2 — Pengantar Basis Data & Perintah DDL MySQL
#
# Bab ini menjelaskan konsep dasar basis data, pengenalan MySQL, cara mengakses MySQL melalui client (CLI), tipe data umum, dan perintah dasar Data Definition Language (DDL).
#
# <br>
#
# # 🧩 Apa Itu Basis Data?
#
# Basis data adalah kumpulan informasi yang terorganisasi dan dapat diakses, dikelola, serta diperbarui dengan mudah.
# Fungsi utamanya adalah menyimpan data secara terstruktur dan menjaga konsistensi informasi.
#
# ---
#
# # 🏛 Apa Itu DBMS?
#
# *DBMS (Database Management System)* adalah perangkat lunak yang digunakan untuk membuat, mengelola, dan mengakses basis data.
#
# Contoh DBMS:
# - MySQL
# - PostgreSQL
# - Oracle
# - SQL Server
#
# DBMS bertugas menangani:
# - penyimpanan data
# - keamanan
# - integritas
# - pengambilan data
# - optimasi
#
# ---
#
# # 🐬 Pengenalan MySQL
#
# *MySQL* adalah salah satu DBMS berbasis SQL paling populer yang bersifat open-source.
# Umumnya digunakan untuk:
# - aplikasi web
# - sistem informasi
# - e-commerce
# - aplikasi skala besar
#
# MySQL sering dipaketkan dalam stack seperti:
# - *Laragon*
# - *XAMPP*
# - *LAMP/WAMP/MAMP*
#
# ---
#
# # 🖥 Cara Mengakses MySQL (Client / CLI)
#
# Untuk masuk ke MySQL melalui terminal (Command Line Interface), gunakan:
#
# `mysql -u root -p`
#
# Penjelasan:
# - `-u root` → login sebagai user root
# - `-p` → meminta password
#
# Setelah dijalankan, akan muncul prompt untuk memasukkan password MySQL.
#
# ### 📌 Cara Keluar dari MySQL
#
# Gunakan perintah:
#
# `exit;`
#
# <br>
#
# ---
#
# # 📊 Tipe Data dalam MySQL
#
# MySQL memiliki beberapa kategori tipe data:
#
# <br>
#
# ## 🔢 1. Numeric Types
# Contoh:
# - `INT` → bilangan bulat
# - `FLOAT` → bilangan pecahan
# - `DOUBLE` → pecahan presisi tinggi
# - `DECIMAL` → angka dengan format desimal tetap
#
#
#
# ## 🔤 2. String Types
# Contoh:
# - `CHAR(n)` → panjang tetap
# - `VARCHAR(n)` → panjang variabel
# - `TEXT` → teks panjang
#
#
#
# ## 🕒 3. Date & Time Types
# Contoh:
# - `DATE` → format YYYY-MM-DD
# - `TIME` → format HH:MM:SS
# - `DATETIME` → gabungan tanggal dan waktu
#
# ---
#
# # 📁 Perintah DDL Dasar (CREATE, SHOW, USE, DROP)
#
# **DDL (Data Definition Language)** digunakan untuk membuat, melihat, memilih, dan menghapus database.
#
# <br>
#
# ## 🟩 1. Membuat database
# ```CREATE DATABASE nama_database;```
#
# ## 🟩 2. Melihat  database
# ```SHOW  DATABASES;```
#
# ## 🟩 3. Membuat tabel
# ```CREATE TABLE nama_tabel;```
#
# ## 🟩 4. Melihat tabel
# ```SHOW TABLES;```
#
# ## 🟩 5. Memilih database
# ```USE nama_database;```
#
# ## 🟩 6. Memilih tabel
# ```USE nama_tabel;```
#
# ## 🟩 7. Menghapus database
# ```DROP DATABASE nama_database;```
#
# <br>
